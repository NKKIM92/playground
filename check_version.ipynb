# %%
# anaconda version: 23.3.1
# !conda --version
# Out:
# conda 23.3.1

# %%
# python 3.10.9
import sys
sys.version
# Out:
# '3.10.9 (main, Mar  1 2023, 18:23:06) [GCC 11.2.0]'

# %%
# numpy 1.23.5
import numpy
numpy.__version__
# Out:
# '1.23.5'

# %%
# pandas 1.5.3
import pandas
pandas.__version__
# Out:
# '1.5.3'

# %%
# sklearn 1.2.1
import sklearn
sklearn.__version__
# Out:
# '1.2.1'

# %%
# matplotlib 3.7.0
import matplotlib
matplotlib.__version__
# Out:
# '3.7.0'

# %%
# seaborn 0.12.2
import seaborn
seaborn.__version__
# Out:
# '0.12.2'

# %%
# mlxtend 0.23.1   (아래는 에러 발생)
import mlxtend
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 # mlxtend 0.23.1   (아래는 에러 발생)
# ----> 2 import mlxtend
#
# ModuleNotFoundError: No module named 'mlxtend'

# %%
# !pip install mlxtend==0.23.1
import mlxtend
# Out:
# Collecting mlxtend==0.23.1
#   Downloading mlxtend-0.23.1-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 20.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.2.1 in ./anaconda3/lib/python3.10/site-packages (from mlxtend==0.23.1) (1.10.0)
# Requirement already satisfied: numpy>=1.16.2 in ./anaconda3/lib/python3.10/site-packages (from mlxtend==0.23.1) (1.23.5)
# Requirement already satisfied: scikit-learn>=1.0.2 in ./anaconda3/lib/python3.10/site-packages (from mlxtend==0.23.1) (1.2.1)
# Requirement already satisfied: joblib>=0.13.2 in ./anaconda3/lib/python3.10/site-packages (from mlxtend==0.23.1) (1.1.1)
# Requirement already satisfied: matplotlib>=3.0.0 in ./anaconda3/lib/python3.10/site-packages (from mlxtend==0.23.1) (3.7.0)
# Requirement already satisfied: pandas>=0.24.2 in ./anaconda3/lib/python3.10/site-packages (from mlxtend==0.23.1) (1.5.3)
# Requirement already satisfied: cycler>=0.10 in ./anaconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in ./anaconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./anaconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./anaconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in ./anaconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./anaconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./anaconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend==0.23.1) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./anaconda3/lib/python3.10/site-packages (from scikit-learn>=1.0.2->mlxtend==0.23.1) (2.2.0)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend==0.23.1) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.1

# %%
# xgboost 1.6.2

# !pip install xgboost==1.6.2
import xgboost
# Out:
# Collecting xgboost==1.6.2
#   Downloading xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl (255.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 6.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: scipy in ./anaconda3/lib/python3.10/site-packages (from xgboost==1.6.2) (1.10.0)
# Requirement already satisfied: numpy in ./anaconda3/lib/python3.10/site-packages (from xgboost==1.6.2) (1.23.5)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.6.2

# %%
# lightgbm 3.3.3

# !pip install lightgbm==3.3.3
import lightgbm
# Out:
# Collecting lightgbm==3.3.3
#   Downloading lightgbm-3.3.3-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.9 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: wheel in ./anaconda3/lib/python3.10/site-packages (from lightgbm==3.3.3) (0.38.4)
# Requirement already satisfied: scikit-learn!=0.22.0 in ./anaconda3/lib/python3.10/site-packages (from lightgbm==3.3.3) (1.2.1)
# Requirement already satisfied: numpy in ./anaconda3/lib/python3.10/site-packages (from lightgbm==3.3.3) (1.23.5)
# Requirement already satisfied: scipy in ./anaconda3/lib/python3.10/site-packages (from lightgbm==3.3.3) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./anaconda3/lib/python3.10/site-packages (from scikit-learn!=0.22.0->lightgbm==3.3.3) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in ./anaconda3/lib/python3.10/site-packages (from scikit-learn!=0.22.0->lightgbm==3.3.3) (1.1.1)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.3

# %%
# yellowbrick 1.4

# !pip install yellowbrick==1.4
import yellowbrick
# Out:
# Collecting yellowbrick==1.4
#   Downloading yellowbrick-1.4-py3-none-any.whl (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.2/274.2 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.0 in ./anaconda3/lib/python3.10/site-packages (from yellowbrick==1.4) (1.23.5)
# Requirement already satisfied: cycler>=0.10.0 in ./anaconda3/lib/python3.10/site-packages (from yellowbrick==1.4) (0.11.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in ./anaconda3/lib/python3.10/site-packages (from yellowbrick==1.4) (3.7.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in ./anaconda3/lib/python3.10/site-packages (from yellowbrick==1.4) (1.2.1)
# Requirement already satisfied: scipy>=1.0.0 in ./anaconda3/lib/python3.10/site-packages (from yellowbrick==1.4) (1.10.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./anaconda3/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.4) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.4) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in ./anaconda3/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.4) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./anaconda3/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.4) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./anaconda3/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.4) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./anaconda3/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.4) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./anaconda3/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.4) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in ./anaconda3/lib/python3.10/site-packages (from scikit-learn>=1.0.0->yellowbrick==1.4) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./anaconda3/lib/python3.10/site-packages (from scikit-learn>=1.0.0->yellowbrick==1.4) (2.2.0)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.4) (1.16.0)
# Installing collected packages: yellowbrick
# Successfully installed yellowbrick-1.4
